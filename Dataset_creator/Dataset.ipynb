# %%
#mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#importing the libraries
from PIL import Image
import requests
from io import BytesIO
from torchvision import models
import torch
from torchvision import transforms
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import random
import os 
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#path = '/content/drive/MyDrive/Vision/Validation_Test/'
path = '/content/drive/MyDrive/Vision/Dataset48/'

folders_training = ['Arringatore', 'Atena', 'Atena armata', 'Demostene', 'Dioniso', 'Era Barberini', 'Ercole', 'Kouros_da_Tenea', 'Minerva_Tritonia', 'Poseidone', 'Zeus']
#folders_validation = ['Arringatore_valid', 'Atena_valid', 'Atena_armata_valid', 'Demostene_valid', 'Dioniso_valid', 'Era_barberini_valid', 'Ercole_valid', 'Kouros_da_tenea_valid', 'Minerva_tritonia_valid', 'Poseidone_valid', 'Zeus_valid']
#folders_test = ['Arringatore_test', 'Atena_test', 'Atena_armata_test', 'Demostene_test', 'Dioniso_test', 'Era_barberini_test', 'Ercole_test', 'Kouros_da_tenea_test', 'Minerva_tritonia_test', 'Poseidone_test', 'Zeus_test']

# %%
from torchvision import transforms

transform = transforms.Compose([transforms.Resize(256), transforms.CenterCrop(256), transforms.ToTensor()])
 #transforms.CenterCrop(224),
 #transforms.Normalize( mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

change = transforms.ColorJitter(brightness=(0.5,1.5), contrast=(1), saturation=(0.5,1.5), hue=(-0.1,0.1))

# %%
#appending the pics to the training data list
data = {}
for lab in folders_training:
  print(lab)
  adress = path + lab
  training_data = []
  for img in os.listdir(adress):
    img = Image.open(os.path.join(adress,img))
    img2 = change(img)
    img3 = change(img)
    img_t = transform(img)
    img_t2 = transform(img2)
    img_t3 = transform(img3)
    batch_t = torch.unsqueeze(img_t, 0)
    batch_t2 = torch.unsqueeze(img_t2, 0)
    batch_t3 = torch.unsqueeze(img_t3, 0)

    training_data.append(batch_t)
    training_data.append(batch_t2)
    training_data.append(batch_t3)
  data[lab] = training_data
# Out:
# Arringatore
# Atena
# Atena armata
# Demostene
# Dioniso
# Era Barberini
# Ercole
# Kouros_da_Tenea
# Minerva_Tritonia
# Poseidone
# Zeus

# %%
#appending the pics to the training data list
valid_data = []
for lab in folders_validation:
  print(lab)
  adress = path + lab
  for img in os.listdir(adress):
    img = Image.open(os.path.join(adress,img))
    img_t = transform(img)
    batch_t = torch.unsqueeze(img_t, 0)

    valid_data.append(batch_t)
# Out:
# Altre
# Arringatore
# Atena
# Atena armata
# Demostene
# Dioniso
# Era Barberini
# Ercole
# Kouros_da_Tenea
# Minerva_Tritonia
# Poseidone
# Zeus

# %%
#torch.save(training_data, '/content/drive/MyDrive/Vision/Validation_Test/test48.pt')
torch.save(data, '/content/drive/MyDrive/Vision/Dataset48/dict.pt')

# %%
#t = torch.load('/content/drive/MyDrive/Vision/Validation_Test/test48.pt')
t = torch.load('/content/drive/MyDrive/Vision/Validation_Test/test48.pt')

# %%
len(training_data)
# Out:
# 1584

# %% [markdown]
# Add video

# %%
import torch
import torchvision
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import random
import torchvision.transforms as transforms
from PIL import Image

# %%
video_path = "/content/drive/MyDrive/Vision/Try/zeus.mp4"

#split video in frames
vidcap = cv2.VideoCapture(video_path)

success,image = vidcap.read()
video = []
statistic = []
count = 0
while success:
  success, frame = vidcap.read()
  #cv2.imwrite("frame%d.jpg" % count, image)     # save frame as JPEG file      
  #success,image = vidcap.read()
  video.append(frame)
  statistic.append(success)
  #print('Read a new frame: ', success)
  count += 1

#convert frames in tensor
t = transforms.ToPILImage()
cut = transforms.Compose([transforms.Resize(256), transforms.CenterCrop(256), transforms.ToTensor()])
lista = []

for i in range(0, len(video)-2):
  image = t(video[i])
  img = cut(image)
  #img = torch.rot90(img, 1, [2, 1]) #rotate image of 90 degrees to make it right
  batch_t = torch.unsqueeze(img, 0)
  lista.append(batch_t)

# %%
len(lista)
# Out:
# 375

# %%
print(len(data['Zeus']))
# Out:
# 519

# %%
for i in lista:
  data['Zeus'].append(i)

# %%
folders_training = ['Arringatore', 'Atena', 'Atena armata', 'Demostene', 'Dioniso', 'Era Barberini', 'Ercole', 'Kouros_da_Tenea', 'Minerva_Tritonia', 'Poseidone', 'Zeus']

# %%
end = []
for i in data:
  for j in range(0, 450):
    end.append(data[i][j])

# %%
len(end)
# Out:
# 4950

# %%
#torch.save(training_data, '/content/drive/MyDrive/Vision/Validation_Test/test48.pt')
torch.save(end, '/content/drive/MyDrive/Vision/Dataset48/train_video.pt')

# %%
#t = torch.load('/content/drive/MyDrive/Vision/Validation_Test/test48.pt')
t = torch.load('/content/drive/MyDrive/Vision/Dataset48/train_video.pt')

# %%
len(t)
# Out:
# 4950
